# %%
import pandas as pd

# %%
dataset = pd.read_csv("USvideos.csv")

# %%
dataset
# Out:
#           video_id trending_date  \
# 0      2kyS6SvSYSE      17.14.11
# 1      1ZAPwfrtAFY      17.14.11
# 2      5qpjK5DgCt4      17.14.11
# 3      puqaWrEC7tY      17.14.11
# 4      d380meD0W0M      17.14.11
# ...            ...           ...
# 40944  BZt0qjTWNhw      18.14.06
# 40945  1h7KV2sjUWY      18.14.06
# 40946  D6Oy4LfoqsU      18.14.06
# 40947  oV0zkMe1K8s      18.14.06
# 40948  ooyjaVdt-jA      18.14.06
#
#                                                    title  \
# 0                     WE WANT TO TALK ABOUT OUR MARRIAGE
# 1      The Trump Presidency: Last Week Tonight with J...
# 2      Racist Superman | Rudy Mancuso, King Bach & Le...
# 3                       Nickelback Lyrics: Real or Fake?
# 4                               I Dare You: GOING BALD!?
# ...                                                  ...
# 40944                       The Cat Who Caught the Laser
# 40945                         True Facts : Ant Mutualism
# ...

# %%
newdataset1 = dataset.drop(["video_id","trending_date"],axis=1)

# %%
newdataset1
# Out:
#                                                    title  \
# 0                     WE WANT TO TALK ABOUT OUR MARRIAGE
# 1      The Trump Presidency: Last Week Tonight with J...
# 2      Racist Superman | Rudy Mancuso, King Bach & Le...
# 3                       Nickelback Lyrics: Real or Fake?
# 4                               I Dare You: GOING BALD!?
# ...                                                  ...
# 40944                       The Cat Who Caught the Laser
# 40945                         True Facts : Ant Mutualism
# 40946  I GAVE SAFIYA NYGAARD A PERFECT HAIR MAKEOVER ...
# 40947                How Black Panther Should Have Ended
# 40948  Official Call of Duty®: Black Ops 4 — Multipla...
#
#                   channel_title  category_id              publish_time  \
# 0                  CaseyNeistat           22  2017-11-13T17:13:01.000Z
# 1               LastWeekTonight           24  2017-11-13T07:30:00.000Z
# ...

# %%
newdataset1.to_csv("UsVideosNew.csv")

# %%
newdataset1.to_csv("UsVideosNew.csv",index=False)

# %%
exceldataset = pd.read_excel("Kitap1.xlsx")

# %%
exceldataset
# Out:
#        Hafta  Toplam Talep Sayısı  Talep Türü Yeni Geliştirme  \
# 0   21.Hafta                   15                          15
# 1   22.Hafta                   13                          13
# 2   23.Hafta                   15                          15
# 3   24.Hafta                   11                          11
# 4   25.Hafta                   12                          12
# 5   26.Hafta                   16                          16
# 6   27.Hafta                    9                           9
# 7   28.Hafta                   13                          13
# 8   29.Hafta                   14                          14
# 9   30.Hafta                   22                          22
# 10  31.Hafta                   19                          16
# 11  32.Hafta                   20                          13
# 12  33.Hafta                   15                          14
# 13  34.Hafta                   10                          10
# ...

# %%
new = pd.read_html("https://www.contextures.com/xlsampledata01.html")

# %%
new
# Out:
# [                                                   0
#  0  Key Skills > Sample Data Excel Sample Data Thi...,
#                                                     0
#  0  Why Use Sample Data in Excel? \tThis page has ...,
#                                                     0
#  0  Sample Data - Insurance Policies  This sample ...,
#                                                     0
#  0  Sample Data - Workplace Safety  This sample fi...,
#                                                     0
#  0  Sample Data - Hockey Players  This sample file...,
#                                                     0
#  0  Sample Data - Winter Athletes  This sample Exc...,
#                                                     0
#  0  Sample Data - Football Players  This sample fi...,
#                                                     0
#  0  Sample Data - Food Nutrients  This sample Exce...,
#                                                     0
# ...

# %%
len(new)
# Out:
# 12

# %%
new[0]
# Out:
#                                                    0
# 0  Key Skills > Sample Data Excel Sample Data Thi...

# %%
new[10]
# Out:
#                                                    0
# 0  Create an Excel Table  After you copy the Offi...
